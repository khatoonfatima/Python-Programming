# %% [markdown]
# ***Dictionaries***
#
#
# 1. Introduction to Dictionaries
#
# 2. Creating Dictionaries
#
# 3. Accessing Dictionary Elements
#
# 4. Modifying Dictionary Elements
#
# 5. Dictionary Methods
#
# 6. Iterating Over Dictionaries
#
# 7. Nested Dictionaries
#
# 8. Dictionary Comprehension
#
# 9. Practical Examples and common Errors

# %% [markdown]
# ***Dictionaries***
#
# Dictionaries are unordered collections of items.They stores data in key-value pairs. Keys must be uniques and immutable(e.g strings, numbers, or tuples), while value can be any type.

# %% [markdown]
# **Creating Dictionaries**

# %%
empty_dict={}
print(type(empty_dict))
# Out:
# <class 'dict'>

# %%
empty_dict=dict()
print(type(empty_dict))
# Out:
# <class 'dict'>

# %%
student={"name":"Fatima","age":25,"major":"Computer Science"}
print(student)
# Out:
# {'name': 'Fatima', 'age': 25, 'major': 'Computer Science'}

# %% [markdown]
# **Single key is always used**

# %%
student={"name":"khan","age":25,"age":26}
print(student)
# Out:
# {'name': 'khan', 'age': 26}

# %% [markdown]
# **Accessing dictionary elements**

# %%
student={"name":"Fatima","age":25,"major":"Computer Science"}
print(student)
# Out:
# {'name': 'Fatima', 'age': 25, 'major': 'Computer Science'}

# %%
print(student['major'])
# Out:
# Computer Science

# %%
print(student['age'])
# Out:
# 25

# %% [markdown]
# **Accessing dictionary elements**

# %%
print(student.get('name'))
print(student.get('age'))
print(student.get('major','Not Available'))
# Out:
# Fatima
# 25
# Computer Science

# %% [markdown]
# **Modifying Dictionary Elements**

# %% [markdown]
# Modifying Dictionary Elements
# Dictionary are mutable, so you can add, update or delete elements

# %%
print(student)
# Out:
# {'name': 'Fatima', 'age': 25, 'major': 'Computer Science'}

# %%
student['age']=33 #Update value for the key
print(student)
student["address"]="India" ##Added value a new key and
print(student)
# Out:
# {'name': 'Fatima', 'age': 33, 'major': 'Computer Science'}
# {'name': 'Fatima', 'age': 33, 'major': 'Computer Science', 'address': 'India'}

# %%
del student['major'] #delete key and value pair
print(student)
# Out:
# {'name': 'Fatima', 'age': 33, 'address': 'India'}

# %% [markdown]
# **Dictionary Methods**

# %%
keys=student.keys()
print(keys)
values=student.values()# get all values
print(values)
items=student.items() #get all key value pairs
print(items)
# Out:
# dict_keys(['name', 'age', 'address'])
# dict_values(['Fatima', 33, 'India'])
# dict_items([('name', 'Fatima'), ('age', 33), ('address', 'India')])

# %% [markdown]
# **Shallow Copy**

# %%
student_copy=student
print(student)
print(student_copy)
# Out:
# {'name': 'Fatima', 'age': 33, 'address': 'India'}
# {'name': 'Fatima', 'age': 33, 'address': 'India'}

# %%
student["name"]="Fatima"
print(student)
print(student_copy)
# Out:
# {'name': 'Fatima', 'age': 33, 'address': 'India'}
# {'name': 'Fatima', 'age': 33, 'address': 'India'}

# %%
student_copy1=student.copy() #shallow copy
print(student_copy1)
print(student)
# Out:
# {'name': 'Fatima', 'age': 33, 'address': 'India'}
# {'name': 'Fatima', 'age': 33, 'address': 'India'}

# %%
student['name']="FatimaKha"
print(student_copy1)
print(student)
# Out:
# {'name': 'Fatima', 'age': 33, 'address': 'India'}
# {'name': 'FatimaKha', 'age': 33, 'address': 'India'}

# %% [markdown]
# **Iterating Over Dictionaries**

# %% [markdown]
# You can use loops to iterate over dictionaries, keys, values, or items
# Iterating over keys

# %%
for keys in student.keys():
  print(keys)
# Out:
# name
# age
# address

# %% [markdown]
# Iterate over values

# %%
for values in student.values():
  print(values)
# Out:
# FatimaKha
# 33
# India

# %% [markdown]
# Iterate over key values pairs

# %%
for keys,value in student.items():
  print(keys,value)
# Out:
# name FatimaKha
# age 33
# address India

# %% [markdown]
# **Nested Dictionaries**

# %%
students={
    "student1":{"name":"Kosha","age":32},
    "student2":{"name":"Peter","age":35}
}
print(students)
# Out:
# {'student1': {'name': 'Kosha', 'age': 32}, 'student2': {'name': 'Peter', 'age': 35}}

# %% [markdown]
# **Access nested dictionaries elements**

# %%
print(students["student2"]["name"])
print(students["student2"]["age"])
# Out:
# Peter
# 35

# %%
students.items()
# Out:
# dict_items([('student1', {'name': 'Kosha', 'age': 32}), ('student2', {'name': 'Peter', 'age': 35})])

# %% [markdown]
# **Iterating over nested dictionaries**

# %%
for student_id, student_info in  students.items():
  print(f"{student_id}:{student_info}")
  for key,value in student_info.items():
    print(f"{key}:{value}")
# Out:
# student1:{'name': 'Kosha', 'age': 32}
# name:Kosha
# age:32
# student2:{'name': 'Peter', 'age': 35}
# name:Peter
# age:35

# %% [markdown]
# **Iterating over nested dictionaries**

# %%
for student_id,student_info in students.items():
  print(student_id)
  print(student_info)
  for key,value in student_info.items():
    print(key,value)
# Out:
# student1
# {'name': 'Kosha', 'age': 32}
# name Kosha
# age 32
# student2
# {'name': 'Peter', 'age': 35}
# name Peter
# age 35

# %% [markdown]
# **Dictionary Comprehension**

# %%
squares={x:x**2 for x in range(5)}
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %% [markdown]
# **Conditional dictionary comprehension**

# %%
evens={x:x**2 for x in range(10) if x%2==0}
print(evens)
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %% [markdown]
# **Practical Examples**

# %%
#Use a dictionary to count the frequency of elements in list
numbers=[1,2,2,3,3,3,4,4,4,4]
frequency={}
for number in numbers:
  if number in frequency:
    frequency[number]+=1
  else:
    frequency[number]=1
print(frequency)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4}

# %% [markdown]
# **Merge 2 dictionaries into one**

# %%
dict1={"a":1,"b":2}
dict2={"c":3,"d":4}
merge_dict={**dict1,**dict2}
print(merge_dict)## ** is used if we give any number of key value pair and it append it into the dictionary, this is also called as keyword arguement
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# **Creating and Accessing the dictionary**

# %%
d={i:i**2 for i in range(1,11)}
print(d)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %% [markdown]
# **Accessing Dictionary Elements**

# %%
print(d[5])
print(d)
# Out:
# 25
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
print("Value of Key 5:{d[5]}")
print("Keys: {list(d.keys())}")
# Out:
# Value of Key 5:{d[5]}
# Keys: {list(d.keys())}

# %% [markdown]
# **Dictionary Methods**

# %%
#Another way of creating and accessing the Dictionaries
d1={i:i**2 for i in range(2,22)}
print(d1)
# Out:
# {2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225, 16: 256, 17: 289, 18: 324, 19: 361, 20: 400, 21: 441}

# %% [markdown]
# **Dictionary Methods**

# %% [markdown]
# Add a new key-value pair (11, 121) to the dictionary created in Assignment 1 and then remove the key-value pair with key 1. Print the modified dictionary.

# %%
d
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
d[11]=121
d
#d.pop(1)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121}

# %%
d.pop(1, None) #This is because the pop method is already used in the previous cell
# Out:
# 1

# %% [markdown]
# **Iterating Over Dictionaries**

# %% [markdown]
# Iterate over the dictionary created in Assignment 1 and print each key-value pair.

# %%
for key,value in d.items():
  print(key,value)
# Out:
# 2 4
# 3 9
# 4 16
# 5 25
# 6 36
# 7 49
# 8 64
# 9 81
# 10 100
# 11 121

# %%
d.items() # This is the dictionary that has already created above
# Out:
# dict_items([(2, 4), (3, 9), (4, 16), (5, 25), (6, 36), (7, 49), (8, 64), (9, 81), (10, 100), (11, 121)])

# %% [markdown]
# **Dictionary Comprehensions**

# %% [markdown]
# Create a new dictionary containing the cubes of the first 10 positive integers using a dictionary comprehension. Print the new dictionary

# %%
cubes={i:i**3 for i in range(1,11)}
print(cubes)
# Out:
# {1: 1, 2: 8, 3: 27, 4: 64, 5: 125, 6: 216, 7: 343, 8: 512, 9: 729, 10: 1000}

# %% [markdown]
# **Merging Dictionaries**

# %% [markdown]
# Create two dictionaries : one with keys as the first 5 positive integers and values as their squares, and another with keys as the next 5 positive integers and values as their squares. Merge these dictionaries into a single dictionary and print it.

# %%
dictionary1={i:i**2 for i in range(1,6)}
dictionary2={i:i**2 for i in range(7,12)}
merge_dict=dictionary1|dictionary2
print(merge_dict)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121}

# %%
dictionary1.update(dictionary2)
print(dictionary1)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121}

# %% [markdown]
# **Nested Dictionary**

# %% [markdown]
# Create a nested dictionary representing a student with keys 'name','age','grades', where 'grades' is another distionary with keys 'math', 'science', and 'english'. Print the nested dictionary

# %%
student={'name':'Rahul','age': 32,'grades':{'math':90,'science':85,'english':95}}
print(student)
# Out:
# {'name': 'Rahul', 'age': 32, 'grades': {'math': 90, 'science': 85, 'english': 95}}

# %% [markdown]
# **Dictionary of Lists**

# %% [markdown]
# Create a dictionary where the keys are the first 5 positive integers and the values are lists containing the first 5 multiples of the key. Print the dictionary

# %%
d1={i:list(range(i,i+5)) for i in range(1,6)}
print(d1)
# Out:
# {1: [1, 2, 3, 4, 5], 2: [2, 3, 4, 5, 6], 3: [3, 4, 5, 6, 7], 4: [4, 5, 6, 7, 8], 5: [5, 6, 7, 8, 9]}

# %% [markdown]
# **Dictionary of Tuples**

# %% [markdown]
# Create a dictionary where the keys are the first 5 positive integers and the values are tuples containing the key and its square. Print the dictionary.

# %%
tuple_dict={i: i**2 for i in range(1,6)}
print(tuple_dict)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# **Dictionary and List Conversion**

# %% [markdown]
# Create a dictionary with the first 5 positive integers as keys and their squares as values. Convert the dictionary to a list of tuples and print it.

# %%
d={i: i**2 for i in range(1,6)}
list_of_tuple=list(d.items())
print(list_of_tuple)
# Out:
# [(1, 1), (2, 4), (3, 9), (4, 16), (5, 25)]

# %% [markdown]
# **Dictionary Filtering**

# %% [markdown]
# Create a dictionary with the first 10 positive integers as keys and their squares as values. Create a new dictionary containing only the key-value pairs where the key is even. Print the new dictionary.

# %%
d={i: i**2 for i in range(1,11)}
even_dict={k: v for k, v in d.items() if k % 2 == 0}
print(even_dict)
# Out:
# {2: 4, 4: 16, 6: 36, 8: 64, 10: 100}

# %% [markdown]
# **Dictionary Key and Value Transformation**

# %% [markdown]
# Create a dictionary with the first 5 positive integers as keys and their squares as values. Create a new dictionary with keys and values swapped. Print the new dictionary

# %%
positive_integer={i: i**2 for i in range(1,6)}
print(positive_integer)
swapped_dict={value: key for key, value in positive_integer.items()}
print(swapped_dict)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
# {1: 1, 4: 2, 9: 3, 16: 4, 25: 5}

# %% [markdown]
# **Default Dictionary**

# %% [markdown]
# Create a default dictionary where each key has a default value of an empty list. Add some elements to the lists and print the dictionary.

# %%
from collections import defaultdict
default_dict=defaultdict(list)
default_dict['a'].append(1)
default_dict['a'].append(2)
default_dict['b'].append(3)
print(default_dict)
# Out:
# defaultdict(<class 'list'>, {'a': [1, 2], 'b': [3]})

# %% [markdown]
# **Counting with Dictionaries**

# %% [markdown]
# Write a function that takes a string and returns a dictionary with the count of each character in the string. Print the dictionary.

# %%
def count_chars(s):
    count_dict={}
    for char in s:
        count_dict[char]=count_dict.get(char,0)+1
    return count_dict

string="hello world"
print(count_chars(string))
# Out:
# {'h': 1, 'e': 1, 'l': 3, 'o': 2, ' ': 1, 'w': 1, 'r': 1, 'd': 1}

# %% [markdown]
# **Dictionary and JSON**

# %% [markdown]
# Create a dictionary representing a book with keys 'title','author','year'and 'genre'. Convert the dictionary to a JSON string and print it.

# %%
import json
book={'title':'To kill a Mockingbird',
      'author':'Harper Lee',
      'year':1960,
      'genre':'Fiction'}


book_json=json.dumps(book)
print(book_json)
# Out:
# {"title": "To kill a Mockingbird", "author": "Harper Lee", "year": 1960, "genre": "Fiction"}
